# %% [markdown]
# # TWITTER SOCIAL MEDIA ANALYTICS

# %%
from textblob import TextBlob
import csv
import tweepy
import unidecode
import matplotlib.pyplot as plt
import pandas as pd

# %%
twitter_data = pd.read_csv('results_olympics.csv')

# %%
print(twitter_data.corr())
# Out:
#               author id     retwc  followers   friends  polarity  subjectivity
# author id      1.000000 -0.015499  -0.096720 -0.037553 -0.481605      0.231048
# retwc         -0.015499  1.000000   0.550444 -0.054336  0.158456      0.265516
# followers     -0.096720  0.550444   1.000000 -0.093077  0.113859      0.044199
# friends       -0.037553 -0.054336  -0.093077  1.000000 -0.301584     -0.025493
# polarity      -0.481605  0.158456   0.113859 -0.301584  1.000000      0.581511
# subjectivity   0.231048  0.265516   0.044199 -0.025493  0.581511      1.000000

# %% [markdown]
# # Retweets vs Polarity

# %%
plt.scatter(twitter_data['retwc'], twitter_data['polarity'])
plt.show()

# %% [markdown]
# # Retweets vs subjectivity

# %%
plt.scatter(twitter_data['retwc'], twitter_data['polarity'])
plt.show()

# %%
twitter_data_subjective = twitter_data[twitter_data['subjectivity'] > 0.5]
plt.scatter(twitter_data_subjective['retwc'], twitter_data_subjective['polarity'])
plt.show()

# %% [markdown]
# More subjective tweets get more retweets
